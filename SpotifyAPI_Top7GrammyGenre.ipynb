# %%
## Creating dataframe of top 7 grammy genres
# Data Exploration
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

cid = '3be62ceebcef44a1807e9002adf8d159'
secret = 'bde76e0d3cd54a68b6ca267237bf7e0e'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

artist_name = []
track_name = []
popularity = []
track_id = []
artist_href = []
track_href = []
album_image = []

for i in range(0,50,50):
    track_results = sp.search(q='year:2023', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        artist_href.append(t['artists'][0]['external_urls']['spotify'])
        track_href.append(t['external_urls']['spotify'])
        album_image.append(t['album']['images'][0]['url'])
        
test1_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'album_image' : album_image})
# Out:
# C:\Users\gupta\anaconda3\envs\music\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\gupta\anaconda3\envs\music\Lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\gupta\anaconda3\envs\music\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
# # Making API request - getting the list of genres from Spotify API
# genres = []
# None_counter = 0

# # get a list of all available categories
# categories = sp.categories(limit=20)

# # loop over the categories and extract their names
# for category in categories['categories']['items']:
#     genres.append(category['name'])

# # print the list of genres
# print(genres)
genres = ['Pop', 'Dance/Electronic', 'Rock', 'Rap', 'R&B','Country', 'New Age']

# %%
# Data Exploration

# Now going thorought the 126 genres and request Spotify API to return 112,000 artist name, track name and genre name
# Used for lyrics/genre merge

artist_name = []
track_name = []
genre_name = []
# print(genres)

for genre in genres:
    # print(genre)
    for i in range(0,1000,50):
        q1 = 'genre:'+str(genre)
        genre_results = sp.search(q=q1, type='track', limit=50,offset=i)
        for i, t in enumerate(genre_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            genre_name.append([genre])
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
# Genre Dataframe

# import pandas as pd

genre_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'genre_name' : genre_name})
print(genre_dataframe.shape)
print(genre_dataframe)
# Out:
# (7000, 3)
#           artist_name                                        track_name
# 0         Miley Cyrus                                           Flowers  \
# 1                 SZA                                         Kill Bill
# 2        Taylor Swift                                         Anti-Hero
# 3               Drake                                   Search & Rescue
# 4         FIFTY FIFTY                                 Cupid - Twin Ver.
# ...               ...                                               ...
# 6995       Aggravator                                    Empire of Fire
# 6996    The Radiators                            Long Hard Journey Home
# 6997    The Last King                                          Gomorrah
# 6998        Hang Drum                           Beginning, Nature Sound
# 6999  Gleaming Spires  It's Alright Ma, I'm Only Bleeding (Bonus Track)
#
#      genre_name
# 0         [Pop]
# 1         [Pop]
# 2         [Pop]
# 3         [Pop]
# 4         [Pop]
# ...         ...
# 6995  [New Age]
# 6996  [New Age]
# 6997  [New Age]
# 6998  [New Age]
# 6999  [New Age]
#
# [7000 rows x 3 columns]

# %%
# Data Exploration

genre_dataframe['track_name'] = genre_dataframe['track_name'].apply(lambda row: row.lower())
genre_dataframe['artist_name'] = genre_dataframe['artist_name'].apply(lambda row: row.lower())
genre_dataframe['genre_name'] = genre_dataframe['genre_name'].str[0]

# %%
# Data Exploration

# convert to csv

# import pandas as pd
# genre_dataframe.to_csv ('Downloads/genre_dataframe4.csv', index = False, header=True)

# %%
# Making API request - going thorough the 126 genres and request Spotify API to return 112,000 artist name, track name, track_href and genre name

artist_name = []
track_name = []
genre_name = []
track_id = []
artist_href = []
track_href = []
album_image = []

# Set up Spotify API credentials

cid = '3be62ceebcef44a1807e9002adf8d159'
secret = 'bde76e0d3cd54a68b6ca267237bf7e0e'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


for genre in genres:
#     print(genre)
    for i in range(0,300,50):
        q1 = 'genre:'+str(genre)
        genre_results = sp.search(q=q1, type='track', limit=50,offset=i)
#         print(genre_results)
        for i, t in enumerate(genre_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            artist_href.append(t['artists'][0]['external_urls']['spotify'])
            track_href.append(t['external_urls']['spotify'])
            if t['album']['images']:
                album_image.append(t['album']['images'][0]['url'])
            else:
                album_image.append(None)
            genre_name.append([genre])
#             print(genre_name)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
   
spotify_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'artist_href' : artist_href, 'track_href' : track_href, 'genre_name' : genre_name})


spotify_dataframe
# Out:
#           artist_name                      track_name                track_id
# 0         Miley Cyrus                         Flowers  0yLdNVWF3Srea0uzk55zFn  \
# 1                 SZA                       Kill Bill  1Qrg8KqiBpW07V7PNxwwwL
# 2        Taylor Swift                       Anti-Hero  0V3wPSX9ygBnCm8psDIegu
# 3               Drake                 Search & Rescue  7aRCf5cLOFN1U7kvtChY1G
# 4         FIFTY FIFTY               Cupid - Twin Ver.  7FbrGaHYVDmfr7KoLIZnQ7
# ...               ...                             ...                     ...
# 2095    Pet Shop Boys         Give stupidity a chance  03l8XqGCRGlS4uovZaIGHN
# 2096  Portico Quartet                         Rushing  1EgzJVgtEB1It28keVyLI6
# 2097  Clinton Jackson  Age Against the Machine - Live  7BKAbLZZnd6BSGJlWAbTgP
# 2098       Kevin Wood             Strength in Numbers  6RZafUcpIGbA8blvpJZtpe
# 2099       Nitzer Ebb        Murderous - Instrumental  2vs6zWOvp2jaOy2jNvxZk2
#
#                                             artist_href
# 0     https://open.spotify.com/artist/5YGY8feqx7naU7...  \
# 1     https://open.spotify.com/artist/7tYKF4w9nC0nq9...
# 2     https://open.spotify.com/artist/06HL4z0CvFAxyc...
# 3     https://open.spotify.com/artist/3TVXtAsR1Inumw...
# 4     https://open.spotify.com/artist/4GJ6xDCF5jaUqD...
# ...                                                 ...
# 2095  https://open.spotify.com/artist/2ycnb8Er79LoH2...
# 2096  https://open.spotify.com/artist/7sYipTRgDXS2JV...
# 2097  https://open.spotify.com/artist/6F5PxdyBz676RS...
# 2098  https://open.spotify.com/artist/5d5oARgyFJkFS6...
# 2099  https://open.spotify.com/artist/7EnAgffrVyerTW...
#
#                                              track_href genre_name
# 0     https://open.spotify.com/track/0yLdNVWF3Srea0u...      [Pop]
# 1     https://open.spotify.com/track/1Qrg8KqiBpW07V7...      [Pop]
# 2     https://open.spotify.com/track/0V3wPSX9ygBnCm8...      [Pop]
# 3     https://open.spotify.com/track/7aRCf5cLOFN1U7k...      [Pop]
# 4     https://open.spotify.com/track/7FbrGaHYVDmfr7K...      [Pop]
# ...                                                 ...        ...
# 2095  https://open.spotify.com/track/03l8XqGCRGlS4uo...  [New Age]
# 2096  https://open.spotify.com/track/1EgzJVgtEB1It28...  [New Age]
# 2097  https://open.spotify.com/track/7BKAbLZZnd6BSGJ...  [New Age]
# 2098  https://open.spotify.com/track/6RZafUcpIGbA8bl...  [New Age]
# 2099  https://open.spotify.com/track/2vs6zWOvp2jaOy2...  [New Age]
#
# [2100 rows x 6 columns]

# %%
# Data Cleanup - get rid of [] in genre_name column

spotify_dataframe['genre_name'] = spotify_dataframe['genre_name'].str[0]
print(spotify_dataframe)
# Out:
#           artist_name                      track_name                track_id
# 0         Miley Cyrus                         Flowers  0yLdNVWF3Srea0uzk55zFn  \
# 1                 SZA                       Kill Bill  1Qrg8KqiBpW07V7PNxwwwL
# 2        Taylor Swift                       Anti-Hero  0V3wPSX9ygBnCm8psDIegu
# 3               Drake                 Search & Rescue  7aRCf5cLOFN1U7kvtChY1G
# 4         FIFTY FIFTY               Cupid - Twin Ver.  7FbrGaHYVDmfr7KoLIZnQ7
# ...               ...                             ...                     ...
# 2095    Pet Shop Boys         Give stupidity a chance  03l8XqGCRGlS4uovZaIGHN
# 2096  Portico Quartet                         Rushing  1EgzJVgtEB1It28keVyLI6
# 2097  Clinton Jackson  Age Against the Machine - Live  7BKAbLZZnd6BSGJlWAbTgP
# 2098       Kevin Wood             Strength in Numbers  6RZafUcpIGbA8blvpJZtpe
# 2099       Nitzer Ebb        Murderous - Instrumental  2vs6zWOvp2jaOy2jNvxZk2
#
#                                             artist_href
# 0     https://open.spotify.com/artist/5YGY8feqx7naU7...  \
# 1     https://open.spotify.com/artist/7tYKF4w9nC0nq9...
# 2     https://open.spotify.com/artist/06HL4z0CvFAxyc...
# 3     https://open.spotify.com/artist/3TVXtAsR1Inumw...
# 4     https://open.spotify.com/artist/4GJ6xDCF5jaUqD...
# ...                                                 ...
# 2095  https://open.spotify.com/artist/2ycnb8Er79LoH2...
# 2096  https://open.spotify.com/artist/7sYipTRgDXS2JV...
# 2097  https://open.spotify.com/artist/6F5PxdyBz676RS...
# 2098  https://open.spotify.com/artist/5d5oARgyFJkFS6...
# 2099  https://open.spotify.com/artist/7EnAgffrVyerTW...
#
#                                              track_href genre_name
# 0     https://open.spotify.com/track/0yLdNVWF3Srea0u...        Pop
# 1     https://open.spotify.com/track/1Qrg8KqiBpW07V7...        Pop
# 2     https://open.spotify.com/track/0V3wPSX9ygBnCm8...        Pop
# 3     https://open.spotify.com/track/7aRCf5cLOFN1U7k...        Pop
# 4     https://open.spotify.com/track/7FbrGaHYVDmfr7K...        Pop
# ...                                                 ...        ...
# 2095  https://open.spotify.com/track/03l8XqGCRGlS4uo...    New Age
# 2096  https://open.spotify.com/track/1EgzJVgtEB1It28...    New Age
# 2097  https://open.spotify.com/track/7BKAbLZZnd6BSGJ...    New Age
# 2098  https://open.spotify.com/track/6RZafUcpIGbA8bl...    New Age
# 2099  https://open.spotify.com/track/2vs6zWOvp2jaOy2...    New Age
#
# [2100 rows x 6 columns]

# %%
# Data Exploration

# using groupby to check for duplicates

grouped = spotify_dataframe.groupby(['artist_name','track_name'], as_index=True).size()
grouped[grouped > 1].count()
# Out:
# 211

# %%
# Data Cleanup - dropping duplicates based on artist_name and track_name

# dropping those values

spotify_dataframe.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
# Data Exploration

# making sure they are gone

grouped_after_dropping = spotify_dataframe.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
# Data Exploration

# how to check duplicates

spotify_dataframe[spotify_dataframe.duplicated(subset=['artist_name','track_name'],keep=False)].count()
# Out:
# artist_name    0
# track_name     0
# track_id       0
# artist_href    0
# track_href     0
# genre_name     0
# dtype: int64

# %%
# Data Exploration

spotify_dataframe.shape
# Out:
# (1837, 6)

# %%
# Making API request - use Spotipy to request Spotify API and return audio features for 112,000 tracks from sound_dataframe in batches of 100

rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(spotify_dataframe['track_id']),batchsize):
    batch = spotify_dataframe['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
# Data Exploration

audio_features_df = pd.DataFrame.from_dict(rows,orient='columns')
print("Shape of the dataset:", audio_features_df.shape)
# Out:
# Shape of the dataset: (1837, 18)

# %%
# Data Exploration

audio_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      1837 non-null   float64
#  1   energy            1837 non-null   float64
#  2   key               1837 non-null   int64
#  3   loudness          1837 non-null   float64
#  4   mode              1837 non-null   int64
#  5   speechiness       1837 non-null   float64
#  6   acousticness      1837 non-null   float64
#  7   instrumentalness  1837 non-null   float64
#  8   liveness          1837 non-null   float64
#  9   valence           1837 non-null   float64
#  10  tempo             1837 non-null   float64
#  11  type              1837 non-null   object
#  12  id                1837 non-null   object
#  13  uri               1837 non-null   object
#  14  track_href        1837 non-null   object
#  15  analysis_url      1837 non-null   object
#  16  duration_ms       1837 non-null   int64
#  17  time_signature    1837 non-null   int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 258.5+ KB

# %%
# Data Cleanup - dropping and renaming columns

columns_to_drop = ['analysis_url','type','uri', 'track_href','time_signature']
audio_features_df.drop(columns_to_drop, axis=1,inplace=True)
audio_features_df.rename(columns={'id': 'track_id'}, inplace=True)
audio_features_df.shape
# Out:
# (1837, 13)

# %%
# Data Exploration

audio_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      1837 non-null   float64
#  1   energy            1837 non-null   float64
#  2   key               1837 non-null   int64
#  3   loudness          1837 non-null   float64
#  4   mode              1837 non-null   int64
#  5   speechiness       1837 non-null   float64
#  6   acousticness      1837 non-null   float64
#  7   instrumentalness  1837 non-null   float64
#  8   liveness          1837 non-null   float64
#  9   valence           1837 non-null   float64
#  10  tempo             1837 non-null   float64
#  11  track_id          1837 non-null   object
#  12  duration_ms       1837 non-null   int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 186.7+ KB

# %%
# Data Cleanup - now we merge user inner to make sure we only keep track ids present

clean_df = pd.merge(spotify_dataframe,audio_features_df,on='track_id',how='inner')
clean_df.head()
# Out:
#     artist_name         track_name                track_id
# 0   Miley Cyrus            Flowers  0yLdNVWF3Srea0uzk55zFn  \
# 1           SZA          Kill Bill  1Qrg8KqiBpW07V7PNxwwwL
# 2  Taylor Swift          Anti-Hero  0V3wPSX9ygBnCm8psDIegu
# 3         Drake    Search & Rescue  7aRCf5cLOFN1U7kvtChY1G
# 4   FIFTY FIFTY  Cupid - Twin Ver.  7FbrGaHYVDmfr7KoLIZnQ7
#
#                                          artist_href
# 0  https://open.spotify.com/artist/5YGY8feqx7naU7...  \
# 1  https://open.spotify.com/artist/7tYKF4w9nC0nq9...
# 2  https://open.spotify.com/artist/06HL4z0CvFAxyc...
# 3  https://open.spotify.com/artist/3TVXtAsR1Inumw...
# 4  https://open.spotify.com/artist/4GJ6xDCF5jaUqD...
#
#                                           track_href genre_name  danceability
# 0  https://open.spotify.com/track/0yLdNVWF3Srea0u...        Pop         0.707  \
# 1  https://open.spotify.com/track/1Qrg8KqiBpW07V7...        Pop         0.644
# 2  https://open.spotify.com/track/0V3wPSX9ygBnCm8...        Pop         0.637
# 3  https://open.spotify.com/track/7aRCf5cLOFN1U7k...        Pop         0.817
# 4  https://open.spotify.com/track/7FbrGaHYVDmfr7K...        Pop         0.783
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness
# 0   0.681    0    -4.325     1       0.0668        0.0632          0.000005  \
# 1   0.735    8    -5.747     1       0.0391        0.0521          0.144000
# 2   0.643    4    -6.571     1       0.0519        0.1300          0.000002
# 3   0.440   10    -8.482     0       0.0734        0.0603          0.000001
# 4   0.592   11    -8.332     0       0.0331        0.4350          0.000004
#
#    liveness  valence    tempo  duration_ms
# 0    0.0322    0.646  117.999       200455
# 1    0.1610    0.418   88.980       153947
# 2    0.1420    0.533   97.008       200690
# 3    0.3300    0.544  142.024       272113
# 4    0.3470    0.726  120.018       174253

# %%
# Data Exploration

clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       1837 non-null   object
#  1   track_name        1837 non-null   object
#  2   track_id          1837 non-null   object
#  3   artist_href       1837 non-null   object
#  4   track_href        1837 non-null   object
#  5   genre_name        1837 non-null   object
#  6   danceability      1837 non-null   float64
#  7   energy            1837 non-null   float64
#  8   key               1837 non-null   int64
#  9   loudness          1837 non-null   float64
#  10  mode              1837 non-null   int64
#  11  speechiness       1837 non-null   float64
#  12  acousticness      1837 non-null   float64
#  13  instrumentalness  1837 non-null   float64
#  14  liveness          1837 non-null   float64
#  15  valence           1837 non-null   float64
#  16  tempo             1837 non-null   float64
#  17  duration_ms       1837 non-null   int64
# dtypes: float64(9), int64(3), object(6)
# memory usage: 258.5+ KB

# %%
# Data Exploration

# make sure no duplicates

clean_df[clean_df.duplicated(subset=['artist_name','track_name'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [artist_name, track_name, track_id, artist_href, track_href, genre_name, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms]
# Index: []

# %%
# Data Cleanup - making everything lower case

clean_df['track_name'] = clean_df['track_name'].apply(lambda row: row.lower())
clean_df['artist_name'] = clean_df['artist_name'].apply(lambda row: row.lower())

# %%
# convert to csv


clean_df.to_csv ('Downloads/spotify_df_Top7GrammyGenre.csv', index = False, header=True)
